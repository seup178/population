# %%
import numpy as np
import pandas as pd
from sklearn.preprocessing import MinMaxScaler
from keras.models import Sequential
from keras.layers import LSTM, Dense

# %%
# 데이터 로드 및 전처리
data = pd.read_csv('성별_전체_추계인구_유소년노년.csv', encoding='euc-kr')
data.set_index(['성별', '연령별'], inplace=True)
data = data.T
data.index = pd.to_numeric(data.index, errors='coerce')
data = data.dropna().sort_index()

# %%
# 유소년, 생산연령, 노년 인구 데이터를 추출
youth_population = data.loc[:, ('전체', '유소년')].values
working_population = data.loc[:, ('전체', '생산연령')].values
elderly_population = data.loc[:, ('전체', '노년')].values

# 데이터 정규화
scaler = MinMaxScaler(feature_range=(0, 1))
youth_population_scaled = scaler.fit_transform(youth_population.reshape(-1, 1))
working_population_scaled = scaler.fit_transform(working_population.reshape(-1, 1))
elderly_population_scaled = scaler.fit_transform(elderly_population.reshape(-1, 1))

# %%
# LSTM 모델을 위한 데이터셋 준비
def create_dataset(dataset, time_step=1):
    dataX, dataY = [], []
    for i in range(len(dataset) - time_step - 1):
        a = dataset[i:(i + time_step), 0]
        dataX.append(a)
        dataY.append(dataset[i + time_step, 0])
    return np.array(dataX), np.array(dataY)

time_step = 3
youth_X, youth_y = create_dataset(youth_population_scaled, time_step)
working_X, working_y = create_dataset(working_population_scaled, time_step)
elderly_X, elderly_y = create_dataset(elderly_population_scaled, time_step)

# 데이터 모양 변환 [samples, time steps, features]
youth_X = youth_X.reshape(youth_X.shape[0], youth_X.shape[1], 1)
working_X = working_X.reshape(working_X.shape[0], working_X.shape[1], 1)
elderly_X = elderly_X.reshape(elderly_X.shape[0], elderly_X.shape[1], 1)

# %%
# LSTM 모델 구축 및 훈련 함수
def create_and_train_lstm_model(X_train, y_train, epochs=100, batch_size=1):
    model = Sequential()
    model.add(LSTM(50, return_sequences=True, input_shape=(X_train.shape[1], 1)))
    model.add(LSTM(50, return_sequences=False))
    model.add(Dense(1))
    
    model.compile(optimizer='adam', loss='mean_squared_error')
    model.fit(X_train, y_train, epochs=epochs, batch_size=batch_size, verbose=1)
    
    return model

# %%
# 유소년, 생산연령, 노년 인구 모델 생성 및 훈련
youth_model = create_and_train_lstm_model(youth_X, youth_y, epochs=50)
working_model = create_and_train_lstm_model(working_X, working_y, epochs=50)
elderly_model = create_and_train_lstm_model(elderly_X, elderly_y, epochs=50)
# Out:
# Epoch 1/50
# C:\Users\felic\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\layers\rnn\rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - loss: 0.2618
# Epoch 2/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0122
# Epoch 3/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 995us/step - loss: 0.0041
# Epoch 4/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0035
# Epoch 5/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 980us/step - loss: 0.0035
# Epoch 6/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0027
# Epoch 7/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0030
# Epoch 8/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0052
# Epoch 9/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0028
# Epoch 10/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0051
# Epoch 11/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0028
# Epoch 12/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0023
# Epoch 13/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0042
# Epoch 14/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0024
# Epoch 15/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0045
# Epoch 16/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0026
# Epoch 17/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0023
# Epoch 18/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0023
# Epoch 19/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0016
# Epoch 20/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0021
# Epoch 21/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0032
# Epoch 22/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0036
# Epoch 23/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0033
# Epoch 24/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0025
# Epoch 25/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0032
# Epoch 26/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0026
# Epoch 27/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0017
# Epoch 28/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0041
# Epoch 29/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0031
# Epoch 30/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0020
# Epoch 31/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0026
# Epoch 32/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0027
# Epoch 33/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0022
# Epoch 34/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0019
# Epoch 35/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0038
# Epoch 36/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0025
# Epoch 37/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0049
# Epoch 38/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0022
# Epoch 39/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0029
# Epoch 40/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0038
# Epoch 41/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0025
# Epoch 42/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0017
# Epoch 43/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0029
# Epoch 44/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0023
# Epoch 45/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0018
# Epoch 46/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0026
# Epoch 47/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0024
# Epoch 48/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0030
# Epoch 49/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0026
# Epoch 50/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0021
# Epoch 1/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.2795
# Epoch 2/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0068
# Epoch 3/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0016
# Epoch 4/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 995us/step - loss: 0.0015
# Epoch 5/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0013
# Epoch 6/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0013
# Epoch 7/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0011
# Epoch 8/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 7.0721e-04
# Epoch 9/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 991us/step - loss: 6.6525e-04
# Epoch 10/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 991us/step - loss: 7.1025e-04
# Epoch 11/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3.9549e-04
# Epoch 12/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 4.6236e-04
# Epoch 13/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 2.0813e-04
# Epoch 14/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 2.8928e-04
# Epoch 15/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3.7454e-04
# Epoch 16/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.4577e-04
# Epoch 17/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.7503e-04
# Epoch 18/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3.1810e-04
# Epoch 19/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.4975e-04
# Epoch 20/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.8257e-04
# Epoch 21/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.5822e-04
# Epoch 22/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.7295e-04
# Epoch 23/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.8456e-04
# Epoch 24/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 2.1675e-04
# Epoch 25/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.1220e-04
# Epoch 26/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.7870e-04
# Epoch 27/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.0731e-04
# Epoch 28/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 8.9798e-05
# Epoch 29/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.2182e-04
# Epoch 30/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.1456e-04
# Epoch 31/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.5939e-04
# Epoch 32/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 2.0497e-04
# Epoch 33/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 2.7506e-04
# Epoch 34/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 2.6003e-04
# Epoch 35/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 4.5113e-04
# Epoch 36/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 4.4432e-04
# Epoch 37/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3.3242e-04
# Epoch 38/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3.1078e-04
# Epoch 39/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.2837e-04
# Epoch 40/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 2.7177e-04
# Epoch 41/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 9.6854e-05
# Epoch 42/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.9506e-04
# Epoch 43/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3.5280e-04
# Epoch 44/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 4.0888e-04
# Epoch 45/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 7.7398e-04
# Epoch 46/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 2.8199e-04
# Epoch 47/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 5.3648e-04
# Epoch 48/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.5834e-04
# Epoch 49/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 4.2830e-04
# Epoch 50/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 2.3229e-04
# Epoch 1/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 965us/step - loss: 0.0961
# Epoch 2/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 988us/step - loss: 0.0103
# Epoch 3/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 983us/step - loss: 7.1700e-04
# Epoch 4/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 8.0813e-04
# Epoch 5/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 993us/step - loss: 9.3571e-04
# Epoch 6/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 975us/step - loss: 7.7698e-04
# Epoch 7/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 8.0698e-04
# Epoch 8/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3.7200e-04
# Epoch 9/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 4.3350e-04
# Epoch 10/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3.7989e-04
# Epoch 11/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.6954e-04
# Epoch 12/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 6.0288e-04
# Epoch 13/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 5.9924e-04
# Epoch 14/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 2.7363e-04
# Epoch 15/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 4.7345e-04
# Epoch 16/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3.2781e-04
# Epoch 17/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 2.8158e-04
# Epoch 18/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3.9894e-04
# Epoch 19/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.4720e-04
# Epoch 20/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3.7275e-04
# Epoch 21/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 4.8560e-04
# Epoch 22/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 4.0563e-04
# Epoch 23/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 4.7197e-04
# Epoch 24/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 2.2106e-04
# Epoch 25/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 4.3134e-04
# Epoch 26/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 4.4644e-04
# Epoch 27/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.1920e-04
# Epoch 28/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 7.4360e-04
# Epoch 29/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 4.0002e-04
# Epoch 30/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 5.4856e-04
# Epoch 31/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 2.9148e-04
# Epoch 32/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 5.2153e-04
# Epoch 33/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3.7378e-04
# Epoch 34/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 2.2323e-04
# Epoch 35/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3.2733e-04
# Epoch 36/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3.8010e-04
# Epoch 37/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3.1324e-04
# Epoch 38/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 5.6373e-04
# Epoch 39/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 4.3811e-04
# Epoch 40/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 7.0292e-04
# Epoch 41/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 5.4937e-04
# Epoch 42/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 9.0928e-04
# Epoch 43/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 2.2763e-04
# Epoch 44/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 4.0287e-04
# Epoch 45/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 2.7692e-04
# Epoch 46/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.4858e-04
# Epoch 47/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 4.4418e-04
# Epoch 48/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 2.1825e-04
# Epoch 49/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 6.1508e-04
# Epoch 50/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 4.2979e-04

# %%
def predict_future(model, data, steps=48):
    predictions = []
    current_input = data[-3:].reshape(1, 3, 1)
    for _ in range(steps):
        next_pred = model.predict(current_input)
        predictions.append(next_pred[0, 0])
        current_input = np.append(current_input[:, 1:, :], np.array(next_pred).reshape(1, 1, 1), axis=1)
    return scaler.inverse_transform(np.array(predictions).reshape(-1, 1))

# %%
# 2024년부터 2072년까지 예측
youth_predictions = predict_future(youth_model, youth_population_scaled)
working_predictions = predict_future(working_model, working_population_scaled)
elderly_predictions = predict_future(elderly_model, elderly_population_scaled)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 154ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 154ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 158ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step

# %%
# 예측된 데이터의 길이 확인
print(f"Length of youth_predictions: {len(youth_predictions)}")
print(f"Length of working_predictions: {len(working_predictions)}")
print(f"Length of elderly_predictions: {len(elderly_predictions)}")
# Out:
# Length of youth_predictions: 48
# Length of working_predictions: 48
# Length of elderly_predictions: 48

# %%
# 예측 결과 출력 및 하나의 CSV 파일로 저장
future_years = np.arange(2024, 2024 + len(youth_predictions))  # 길이를 예측된 데이터 길이로 맞추기
predictions_df = pd.DataFrame({
    'Year': future_years,
    '유소년': youth_predictions.flatten(),
    '생산연령': working_predictions.flatten(),
    '노년': elderly_predictions.flatten()
})

# CSV 파일로 저장
predictions_df.to_csv('LSTM결과.csv', index=False, encoding='euc-kr')

# %%
# Out:
#     Year  Youth_Population
# 0   2024      3.894387e+05
# 1   2025      1.410250e+05
# 2   2026     -1.242955e+05
# 3   2027     -3.884001e+05
# 4   2028     -6.446246e+05
# 5   2029     -9.041068e+05
# 6   2030     -1.159384e+06
# 7   2031     -1.410005e+06
# 8   2032     -1.657818e+06
# 9   2033     -1.900002e+06
# 10  2034     -2.136463e+06
# 11  2035     -2.367014e+06
# 12  2036     -2.590510e+06
# 13  2037     -2.806712e+06
# 14  2038     -3.015218e+06
# 15  2039     -3.215527e+06
# 16  2040     -3.407446e+06
# 17  2041     -3.590750e+06
# 18  2042     -3.765279e+06
# 19  2043     -3.931000e+06
# 20  2044     -4.087908e+06
# 21  2045     -4.236073e+06
# 22  2046     -4.375630e+06
# 23  2047     -4.506756e+06
# 24  2048     -4.629675e+06
# 25  2049     -4.744650e+06
# 26  2050     -4.851966e+06
# 27  2051     -4.951946e+06
# 28  2052     -5.044916e+06
# 29  2053     -5.131220e+06
# 30  2054     -5.211208e+06
# 31  2055     -5.285232e+06
# 32  2056     -5.353642e+06
# 33  2057     -5.416780e+06
# 34  2058     -5.474984e+06
# 35  2059     -5.528580e+06
# 36  2060     -5.577881e+06
# 37  2061     -5.623192e+06
# 38  2062     -5.664794e+06
